# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
di = dict(time=np.arange(500).cumsum(), value=np.random.randn(500).cumsum())

# %%
df = pd.DataFrame(di)
df
# Out:
#        time      value
# 0         0  -0.242910
# 1         1  -1.794022
# 2         3  -1.988950
# 3         6  -2.461525
# 4        10  -1.447891
# ..      ...        ...
# 495  122760 -29.036290
# 496  123256 -29.719485
# 497  123753 -27.484310
# 498  124251 -26.519642
# 499  124750 -26.116242
#
# [500 rows x 2 columns]

# %%
sns.relplot(x='time',y='value',data=df)

# %%
sns.catplot(data=df)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()
# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(10, 9))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
flights_long.columns
# Out:
# Index(['year', 'month', 'passengers'], dtype='object')

# %%
type(flights_long)
# Out:
# pandas.core.frame.DataFrame
